# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Creamos el directorio para nuestros archivos
# !cd /content/nmt/

# %%
# Clonamos el repositorio para herramientas de preprocesamiento
# !git clone https://github.com/ymoslem/MT-Preparation.git
# Out:
# Cloning into 'MT-Preparation'...
# remote: Enumerating objects: 268, done.
# remote: Counting objects: 100% (268/268), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 268 (delta 133), reused 189 (delta 97), pack-reused 0
# Receiving objects: 100% (268/268), 69.06 KiB | 1.35 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %%
# Instalamos los requerimientos
# !pip3 install -r MT-Preparation/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.4 MB/s eta 0:00:00
# ...

# %%
def unir_archivos(archivo_destino, *archivos_fuente):
  """
  Une archivos
  """
  with open(archivo_destino, 'a') as destino:
        for archivo_fuente in archivos_fuente:
            with open(archivo_fuente, 'r') as fuente:
                destino.write(fuente.read())

# %%
#Obtiene los archivos de train, dev y test de náhuatl
# !wget https://raw.githubusercontent.com/AmericasNLP/americasnlp2021/main/data/nahuatl-spanish/train.nah
# !wget https://raw.githubusercontent.com/AmericasNLP/americasnlp2021/main/data/nahuatl-spanish/dev.nah
# Out:
# --2023-11-30 00:15:52--  https://raw.githubusercontent.com/AmericasNLP/americasnlp2021/main/data/nahuatl-spanish/train.nah
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2348518 (2.2M) [text/plain]
# Saving to: ‘train.nah’
#
# train.nah           100%[===================>]   2.24M  --.-KB/s    in 0.07s
#
# 2023-11-30 00:15:52 (33.3 MB/s) - ‘train.nah’ saved [2348518/2348518]
#
# --2023-11-30 00:15:52--  https://raw.githubusercontent.com/AmericasNLP/americasnlp2021/main/data/nahuatl-spanish/dev.nah
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# ...

# %%
unir_archivos('nah', 'train.nah', 'dev.nah')

# %%
#Obtiene los archivos de train, dev y test de español
# !wget https://raw.githubusercontent.com/AmericasNLP/americasnlp2021/main/data/nahuatl-spanish/train.es
# !wget https://raw.githubusercontent.com/AmericasNLP/americasnlp2021/main/data/nahuatl-spanish/dev.es
# Out:
# --2023-11-30 00:16:01--  https://raw.githubusercontent.com/AmericasNLP/americasnlp2021/main/data/nahuatl-spanish/train.es
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2480418 (2.4M) [text/plain]
# Saving to: ‘train.es’
#
# train.es            100%[===================>]   2.37M  --.-KB/s    in 0.08s
#
# 2023-11-30 00:16:01 (31.1 MB/s) - ‘train.es’ saved [2480418/2480418]
#
# --2023-11-30 00:16:01--  https://raw.githubusercontent.com/AmericasNLP/americasnlp2021/main/data/nahuatl-spanish/dev.es
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# ...

# %%
unir_archivos('es', 'train.es', 'dev.es')

# %%
# Filter the dataset
# Arguments: source file, target file, source language, target language
# !python3 MT-Preparation/filtering/filter.py es nah es nah
# Out:
# Dataframe shape (rows, columns): (16817, 2)
# --- Rows with Empty Cells Deleted	--> Rows: 16733
# --- Duplicates Deleted			--> Rows: 16119
# --- Source-Copied Rows Deleted		--> Rows: 16044
# --- Too Long Source/Target Deleted	--> Rows: 14783
# --- HTML Removed			--> Rows: 14783
# --- Rows will remain in true-cased	--> Rows: 14783
# --- Rows with Empty Cells Deleted	--> Rows: 14783
# --- Rows Shuffled			--> Rows: 14783
# --- Source Saved: es-filtered.es
# --- Target Saved: nah-filtered.nah

# %%
# !ls MT-Preparation/subwording/
# Out:
# 1-train_bpe.py	1-train_unigram.py  2-subword.py  3-desubword.py

# %%
# Train a SentencePiece model for subword tokenization
# !python3 MT-Preparation/subwording/1-train_unigram.py es-filtered.es nah-filtered.nah
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=es-filtered.es --model_prefix=source --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: es-filtered.es
#   input_format:
#   model_prefix: source
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
# ...

# %%
# Subword the dataset
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model es-filtered.es nah-filtered.nah
# Out:
# Source Model: source.model
# Target Model: target.model
# Source Dataset: es-filtered.es
# Target Dataset: nah-filtered.nah
# Done subwording the source file! Output: es-filtered.es.subword
# Done subwording the target file! Output: nah-filtered.nah.subword

# %%
# Primeras 2 lineas sin subwordZ}|
# !head -n 3 es-filtered.es && echo "-----" && head -n 3 nah-filtered.nah
# Out:
# Para este dicho año de 6 Tochtli , 1238 , hacía cuatro años que Chalchiuhtlatónac Segundo gobernaba como decimotercer tlatohuani de Colhuacan .
# Mi mamá está vieja .
# Este Tochinteuctli gobernó en Huexotla ; y su hermana mayor , Azcuéitl , fue mujer de Matlaccóatl de Azcapotzalco .
# -----
# Auh yn ihcuac ypan in omoteneuh VI Tochtli xihuitl , 1238 años , ca ye iuh nepa nauhxihuitl tlahtocati yn icome ytoca Chalchiuhtlatonac yn icmatlactlomey tlahtohuani Culhuacan .
# No nana ilamahtica .
# Yni yeh Tochintecuhtli Uexotla tlatocat ; auh yn iueltiuh Azcueytl yciuauh muchiuh Matlacouatl Azcapotzalco .

# %%
# First 3 lines after subwording
# !head -n 3 es-filtered.es.subword && echo "---" && tail -n 3  nah-filtered.nah.subword
# Out:
# ▁Para ▁este ▁dicho ▁año ▁de ▁ 6 ▁Tochtl i ▁, ▁ 1 2 3 8 ▁, ▁hacía ▁cuatro ▁años ▁que ▁Chalchiuhtlat ón ac ▁Segund o ▁gobernaba ▁como ▁decimotercer ▁tlatohuan i ▁de ▁Colhuaca n ▁.
# ▁Mi ▁mamá ▁está ▁vieja ▁.
# ▁Este ▁Tochinteuctl i ▁gobern ó ▁en ▁Huexotla ▁; ▁y ▁su ▁hermana ▁mayor ▁, ▁A zcué itl ▁, ▁fue ▁mujer ▁de ▁Matlaccó atl ▁de ▁Azcapotzal co ▁.
# ---
# ▁ AYOPE CHTLI ▁ICUIC
# ▁in ▁occe
# ...

# %%
# Split the dataset into training set, development set, and test set
# Development and test sets should be between 1000 and 5000 segments (here we chose 2000)
# !python3 MT-Preparation/train_dev_split/train_dev_test_split.py 2000 2000 nah-filtered.nah.subword es-filtered.es.subword
# Out:
# Dataframe shape: (14783, 2)
# --- Empty Cells Deleted --> Rows: 14783
# --- Wrote Files
# Done!
# Output files
# nah-filtered.nah.subword.train
# es-filtered.es.subword.train
# nah-filtered.nah.subword.dev
# es-filtered.es.subword.dev
# nah-filtered.nah.subword.test
# es-filtered.es.subword.test

# %%
# !pip install OpenNMT-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.3/257.3 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 34.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 67.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 108.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 17.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 78.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 30.7 MB/s eta 0:00:00
# ...

# %%
# Creación del archivo de configuración
# Usando valores pequeños en vista de que tenemos un corpus limitado
# Para datasets grandes deberian aumentar los valores:
# train_steps, valid_steps, warmup_steps, save_checkpoint_steps, keep_checkpoint
SRC_DATA_NAME = "nah-filtered.nah.subword"
TARGET_DATA_NAME = "es-filtered.es.subword"

config = f'''# config.yaml

## Where the samples will be written
save_data: run

# Rutas de archivos de entrenamiento
#(previamente aplicado subword tokenization)
data:
    corpus_1:
        path_src: {SRC_DATA_NAME}.train
        path_tgt: {TARGET_DATA_NAME}.train
        transforms: [filtertoolong]
    valid:
        path_src: {SRC_DATA_NAME}.dev
        path_tgt: {TARGET_DATA_NAME}.dev
        transforms: [filtertoolong]

# Vocabularios (serán generados por `onmt_build_vocab`)
src_vocab: source.vocab
tgt_vocab: target.vocab

# Tamaño del vocabulario
#(debe concordar con el parametro usado en el algoritmo de subword tokenization)
src_vocab_size: 50000
tgt_vocab_size: 50000

# Filtrado sentencias de longitud mayor a n
# actuara si [filtertoolong] está presente
src_seq_length: 150
src_seq_length: 150

# Tokenizadores
src_subword_model: source.model
tgt_subword_model: target.model

# Archivos donde se guardaran los logs y los checkpoints de modelos
log_file: train.log
save_model: models/model.enes

# Condición de paro si no se obtienen mejoras significativas
# despues de n validaciones
early_stopping: 4

# Guarda un checkpoint del modelo cada n steps
save_checkpoint_steps: 1000

# Mantiene los n ultimos checkpoints
keep_checkpoint: 3

# Reproductibilidad
seed: 3435

# Entrena el modelo maximo n steps
# Default: 100,000
train_steps: 3000

# Corre el set de validaciones (*.dev) despues de n steps
# Defatul: 10,000
valid_steps: 1000

warmup_steps: 1000
report_every: 100

# Numero de GPUs y sus ids
world_size: 1
gpu_ranks: [0]

# Batching
bucket_size: 262144
num_workers: 0
batch_type: "tokens"
batch_size: 4096
valid_batch_size: 2048
max_generator_batches: 2
accum_count: [4]
accum_steps: [0]

# Configuración del optimizador
model_dtype: "fp16"
optim: "adam"
learning_rate: 2
# warmup_steps: 8000
decay_method: "noam"
adam_beta2: 0.998
max_grad_norm: 0
label_smoothing: 0.1
param_init: 0
param_init_glorot: true
normalization: "tokens"

# Configuración del Modelo
encoder_type: transformer
decoder_type: transformer
position_encoding: true
enc_layers: 6
dec_layers: 6
heads: 8
hidden_size: 512
word_vec_size: 512
transformer_ff: 2048
dropout_steps: [0]
dropout: [0.1]
attention_dropout: [0.1]
'''

with open("/config.yaml", "w+") as config_yaml:
  config_yaml.write(config)

# %%
# !cat /content/nmt/practica/config.yaml
# Out:
# # config.yaml
#
# ## Where the samples will be written
# save_data: run
#
# # Rutas de archivos de entrenamiento
# #(previamente aplicado subword tokenization)
# data:
#     corpus_1:
#         path_src: nah-filtered.nah.subword.train
#         path_tgt: es-filtered.es.subword.train
#         transforms: [filtertoolong]
#     valid:
#         path_src: nah-filtered.nah.subword.dev
#         path_tgt: es-filtered.es.subword.dev
#         transforms: [filtertoolong]
#
# # Vocabularios (serán generados por `onmt_build_vocab`)
# src_vocab: source.vocab
# tgt_vocab: target.vocab
#
# # Tamaño del vocabulario
# #(debe concordar con el parametro usado en el algoritmo de subword tokenization)
# src_vocab_size: 50000
# tgt_vocab_size: 50000
#
# # Filtrado sentencias de longitud mayor a n
# # actuara si [filtertoolong] está presente
# src_seq_length: 150
# src_seq_length: 150
#
# # Tokenizadores
# src_subword_model: source.model
# tgt_subword_model: target.model
#
# ...

# %%
# %%time
# !onmt_build_vocab -config /content/nmt/practica/config.yaml -n_sample -1 -num_threads 2
# Out:
# 2023-11-30 00:18:49.677226: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-30 00:18:49.677283: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-30 00:18:49.677328: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-30 00:18:49.685899: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# Check if the GPU is active
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-97ce6390-1389-7c1e-f059-04385128a1ea)

# %%
# Check if the GPU is visable to PyTorch

import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

gpu_memory = torch.cuda.mem_get_info(0)
print("Free GPU memory:", gpu_memory[0]/1024**2, "out of:", gpu_memory[1]/1024**2)
# Out:
# True
# Tesla T4
# Free GPU memory: 14998.8125 out of: 15101.8125

# %%
# !ls
# Out:
# dev.es			      models			      sample_data
# dev.nah			      MT-Preparation		      source.model
# drive			      nah			      source.vocab
# es			      nah-filtered.nah		      target.model
# es-filtered.es		      nah-filtered.nah.subword	      target.vocab
# es-filtered.es.subword	      nah-filtered.nah.subword.dev    train.es
# es-filtered.es.subword.dev    nah-filtered.nah.subword.test   train.log
# es-filtered.es.subword.test   nah-filtered.nah.subword.train  train.nah
# es-filtered.es.subword.train  nmt

# %%
# %%time
# !onmt_train -config /content/nmt/practica/config.yaml
# Out:
# 2023-11-30 00:19:18.052184: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-30 00:19:18.052247: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-30 00:19:18.052286: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-30 00:19:18.060520: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !onmt_translate -model models/model.enes_step_3000.pt -src nah-filtered.nah.subword.test -output es.practice.translated -gpu 0 -min_length 1
# Out:
# 2023-11-30 01:49:25.855861: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-30 01:49:25.855925: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-30 01:49:25.855973: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-30 01:49:25.868829: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !pip install -U -q sentencepiece

# %%
# !python MT-Preparation/subwording/3-desubword.py target.model es.practice.translated
# Out:
# Done desubwording! Output: es.practice.translated.desubword

# %%
# !git clone https://github.com/ymoslem/MT-Evaluation.git
# Out:
# Cloning into 'MT-Evaluation'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 93 (delta 42), reused 4 (delta 1), pack-reused 0
# Receiving objects: 100% (93/93), 18.22 KiB | 2.28 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# !pip install -r MT-Evaluation/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 16.0 MB/s eta 0:00:00
# ...

# %%
# Aplicando desubword para tener la traducción de referencia
# !python MT-Preparation/subwording/3-desubword.py target.model es-filtered.es.subword.test
# Out:
# Done desubwording! Output: es-filtered.es.subword.test.desubword

# %%
# !python MT-Evaluation/BLEU/compute-bleu.py es-filtered.es.subword.test.desubword es.practice.translated.desubword
# Out:
# Reference 1st sentence: Entonces Moquihuixtli▁propuso a▁los de▁Huexotzinco , Cuaochpanco y Matlatzinco que se▁aliaran contra▁nosotros▁los tenochcas .
# MTed 1st sentence: Enseguida Moquihuixtli , tlatohuani de Tlatelolco , alardeó de▁valiente , y▁también▁Tecónal ; no▁así▁Cuacuauhtzin ,▁quien▁les▁advirtió que▁perecerían .
# That's 100 lines that end in a tokenized period ('.')
# It looks like you forgot to detokenize your test data, which may hurt your score.
# If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# BLEU:  8.229766781725349

# %%
# !python evaluate.py --system_output /content/es.practice.translated.desubword --gold_reference /content/es-filtered.es.subword.test.desubword
# Out:
# []
# 2000
# That's 100 lines that end in a tokenized period ('.')
# It looks like you forgot to detokenize your test data, which may hurt your score.
# If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# #### Score Report ####
# chrF2 = 29.88
# BLEU = 8.23
