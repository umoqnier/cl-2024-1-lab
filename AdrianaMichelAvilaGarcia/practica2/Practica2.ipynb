# %% [markdown]
# # Práctica 2: Análisis morfológico (parte 1)

# %% [markdown]
# Obtener 10 oraciones al azar del conjunto de pruebas del corpus SIGMORPH 2022
#
# - Track: Sentences
# - Guardarlas en un objeto pandas [OPCIONAL]

# %%
import random
import requests
import pandas as pd
from nltk.stem.snowball import EnglishStemmer
from nltk.tokenize import wordpunct_tokenize
import spacy
from tabulate import tabulate

# %%
r = requests.get("https://raw.githubusercontent.com/sigmorphon/2022SegmentationST/main/data/spa.word.test.gold.tsv")

def get_files(lang: str, track: str = "word") -> list[str]:
    """Genera una lista de nombres de archivo basados en el idioma y el track

    Parameters:
    ----------
    lang : str
        Idioma para el cual se generarán los nombres de archivo.
    track : str, optional
        Track del shared task de donde vienen los datos (por defecto es "word").

    Returns:
    -------
    list of str
        Una lista de nombres de archivo generados para el idioma y la pista especificados.
    """
    return [
        f"{lang}.{track}.test.gold",
        f"{lang}.{track}.dev",
    ]

def get_raw_corpus(files: list) -> list:
    """Descarga y concatena los datos de los archivos tsv desde una URL base.

    Parameters:
    ----------
    files : list
        Lista de nombres de archivos (sin extensión) que se descargarán
        y concatenarán.

    Returns:
    -------
    list
        Una lista que contiene los contenidos descargados y concatenados
        de los archivos tsv.
    """
    result = []
    for file in files:
        print(f"Downloading {file}.tsv")
        r = requests.get(f"https://raw.githubusercontent.com/sigmorphon/2022SegmentationST/main/data/{file}.tsv")
        response_list = r.text.split("\n")
        result.extend(response_list[:-1])
    return result

# %%
# Nota: el único idioma en la intersección fue el inglés

def get_10_random_sentences():
    files = get_files("eng", "sentence")
    print("files", files)
    raw = get_raw_corpus([files[1]])
    random_lines = random.sample(raw, 10)
    sentences = []
    for line in random_lines:
        sentence, tagged = line.split("\t")
        sentences.append(sentence)
    return sentences

# %% [markdown]
# Usar las bibliotecas spacy y nltk para realizar los siguientes procesos:
# - Stemming (nltk)
# - Lemmatization (spacy)
# - Obtención de información morfologica (spacy)
# - Imprimir la información en pantalla (formato libre)

# %%
# Para que funcione lo siguiente, se sebe tener descargado el modelo en_core_web_sm de spacy.
# Lo puedes descargar ejecutando lo soguiente (en el notebook debe ejecutarse en raw)
# !python -m spacy download en_core_web_sm

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def get_word_analysis(word):
    word_info = {}
    word_info['word'] = word
    stemmer = EnglishStemmer()
    word_info['stem'] = stemmer.stem(word)
    tokens = nlp(word)
    word_info['lemma'] = tokens[0].lemma_
    word_info['morphological_info'] = tokens[0].morph.to_dict()
    return word_info

def get_sentence_analysis(sentence):
    words = wordpunct_tokenize(sentence)
    words_info = []
    for word in words:
        words_info.append(get_word_analysis(word))
    return words_info

# %%
# Imprimir toda la información:
sentences = get_10_random_sentences()

for sent in sentences:
    df_sent = pd.DataFrame(get_sentence_analysis(sent))
    print("Sentence:", sent)
    print(tabulate(df_sent, headers='keys', tablefmt='psql', showindex=False))
# Out:
# files ['eng.sentence.test.gold', 'eng.sentence.dev']
# Downloading eng.sentence.dev.tsv
# Sentence: The Guaranty is dated August 1 , 2000 .
# +----------+----------+----------+--------------------------------------------------------------------------------------+
# | word     | stem     | lemma    | morphological_info                                                                   |
# |----------+----------+----------+--------------------------------------------------------------------------------------|
# | The      | the      | the      | {'Definite': 'Def', 'PronType': 'Art'}                                               |
# | Guaranty | guaranti | guaranty | {'Number': 'Sing'}                                                                   |
# | is       | is       | be       | {'Mood': 'Ind', 'Number': 'Sing', 'Person': '3', 'Tense': 'Pres', 'VerbForm': 'Fin'} |
# | dated    | date     | date     | {'Aspect': 'Perf', 'Tense': 'Past', 'VerbForm': 'Part'}                              |
# | August   | august   | August   | {'Number': 'Sing'}                                                                   |
# | 1        | 1        | 1        | {'NumType': 'Card'}                                                                  |
# | ,        | ,        | ,        | {'PunctType': 'Comm'}                                                                |
# | 2000     | 2000     | 2000     | {'NumType': 'Card'}                                                                  |
# | .        | .        | .        | {'PunctType': 'Peri'}                                                                |
# +----------+----------+----------+--------------------------------------------------------------------------------------+
# Sentence: In this case , following the talent leads me to think that Google will be making an announcement this year that formalizes the Google - Mozilla / Firefox relationship .
# +--------------+--------------+--------------+-----------------------------------------------------------------------+
# | word         | stem         | lemma        | morphological_info                                                    |
# |--------------+--------------+--------------+-----------------------------------------------------------------------|
# | In           | in           | in           | {}                                                                    |
# | this         | this         | this         | {'Number': 'Sing', 'PronType': 'Dem'}                                 |
# | case         | case         | case         | {'Number': 'Sing'}                                                    |
# | ,            | ,            | ,            | {'PunctType': 'Comm'}                                                 |
# | following    | follow       | follow       | {'Aspect': 'Prog', 'Tense': 'Pres', 'VerbForm': 'Part'}               |
# | the          | the          | the          | {'Definite': 'Def', 'PronType': 'Art'}                                |
# | talent       | talent       | talent       | {'Number': 'Sing'}                                                    |
# | leads        | lead         | lead         | {'Number': 'Sing', 'Person': '3', 'Tense': 'Pres', 'VerbForm': 'Fin'} |
# | me           | me           | I            | {'Case': 'Acc', 'Number': 'Sing', 'Person': '1', 'PronType': 'Prs'}   |
# | to           | to           | to           | {}                                                                    |
# | think        | think        | think        | {'VerbForm': 'Inf'}                                                   |
# | that         | that         | that         | {'Number': 'Sing', 'PronType': 'Dem'}                                 |
# | Google       | googl        | Google       | {'Number': 'Sing'}                                                    |
# | will         | will         | will         | {'VerbForm': 'Fin'}                                                   |
# | be           | be           | be           | {'VerbForm': 'Inf'}                                                   |
# | making       | make         | make         | {'Aspect': 'Prog', 'Tense': 'Pres', 'VerbForm': 'Part'}               |
# | an           | an           | an           | {'Definite': 'Ind', 'PronType': 'Art'}                                |
# | announcement | announc      | announcement | {'Number': 'Sing'}                                                    |
# | this         | this         | this         | {'Number': 'Sing', 'PronType': 'Dem'}                                 |
# | year         | year         | year         | {'Number': 'Sing'}                                                    |
# | that         | that         | that         | {'Number': 'Sing', 'PronType': 'Dem'}                                 |
# | formalizes   | formal       | formalize    | {'Number': 'Plur'}                                                    |
# | the          | the          | the          | {'Definite': 'Def', 'PronType': 'Art'}                                |
# | Google       | googl        | Google       | {'Number': 'Sing'}                                                    |
# | -            | -            | -            | {'PunctType': 'Peri'}                                                 |
# | Mozilla      | mozilla      | Mozilla      | {'Number': 'Sing'}                                                    |
# | /            | /            | /            | {'PunctType': 'Peri'}                                                 |
# | Firefox      | firefox      | Firefox      | {'Number': 'Plur'}                                                    |
# | relationship | relationship | relationship | {'Number': 'Sing'}                                                    |
# | .            | .            | .            | {'PunctType': 'Peri'}                                                 |
# +--------------+--------------+--------------+-----------------------------------------------------------------------+
# Sentence: is it still available ?
# +-----------+--------+-----------+--------------------------------------------------------------------------------------+
# | word      | stem   | lemma     | morphological_info                                                                   |
# |-----------+--------+-----------+--------------------------------------------------------------------------------------|
# | is        | is     | be        | {'Mood': 'Ind', 'Number': 'Sing', 'Person': '3', 'Tense': 'Pres', 'VerbForm': 'Fin'} |
# | it        | it     | it        | {'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}               |
# | still     | still  | still     | {}                                                                                   |
# | available | avail  | available | {'Degree': 'Pos'}                                                                    |
# | ?         | ?      | ?         | {'PunctType': 'Peri'}                                                                |
# +-----------+--------+-----------+--------------------------------------------------------------------------------------+
# Sentence: In Texas , BP shut its 460,000 barrels per day refinery and Marathon shut its 72,000 bpd plant .
# +----------+----------+----------+---------------------------------------------------------------------------------------+
# | word     | stem     | lemma    | morphological_info                                                                    |
# |----------+----------+----------+---------------------------------------------------------------------------------------|
# | In       | in       | in       | {}                                                                                    |
# | Texas    | texa     | Texas    | {'Number': 'Sing'}                                                                    |
# | ,        | ,        | ,        | {'PunctType': 'Comm'}                                                                 |
# | BP       | bp       | bp       | {'Number': 'Sing'}                                                                    |
# | shut     | shut     | shut     | {'Tense': 'Past', 'VerbForm': 'Fin'}                                                  |
# | its      | it       | its      | {'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'} |
# | 460      | 460      | 460      | {'NumType': 'Card'}                                                                   |
# | ,        | ,        | ,        | {'PunctType': 'Comm'}                                                                 |
# | 000      | 000      | 000      | {'NumType': 'Card'}                                                                   |
# | barrels  | barrel   | barrel   | {'Number': 'Plur'}                                                                    |
# | per      | per      | per      | {}                                                                                    |
# | day      | day      | day      | {'Number': 'Sing'}                                                                    |
# | refinery | refineri | refinery | {'Number': 'Sing'}                                                                    |
# | and      | and      | and      | {'ConjType': 'Cmp'}                                                                   |
# | Marathon | marathon | marathon | {'VerbForm': 'Inf'}                                                                   |
# | shut     | shut     | shut     | {'Tense': 'Past', 'VerbForm': 'Fin'}                                                  |
# | its      | it       | its      | {'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'} |
# | 72       | 72       | 72       | {'NumType': 'Card'}                                                                   |
# | ,        | ,        | ,        | {'PunctType': 'Comm'}                                                                 |
# | 000      | 000      | 000      | {'NumType': 'Card'}                                                                   |
# | bpd      | bpd      | bpd      | {'Number': 'Sing'}                                                                    |
# | plant    | plant    | plant    | {'Number': 'Sing'}                                                                    |
# | .        | .        | .        | {'PunctType': 'Peri'}                                                                 |
# +----------+----------+----------+---------------------------------------------------------------------------------------+
# Sentence: Kevin A. Boone Accenture -- Houston Consultant -- Energy ( Octel ) 713.837.1638 ( Client ) 281.848.1619 ( C ) 713.306.7940 ( H ) 713.864.4149 Kevin.A.Boone@accenture.com
# +------------+----------+------------+-------------------------------------------+
# | word       | stem     | lemma      | morphological_info                        |
# |------------+----------+------------+-------------------------------------------|
# | Kevin      | kevin    | Kevin      | {'Number': 'Sing'}                        |
# | A          | a        | a          | {'Definite': 'Ind', 'PronType': 'Art'}    |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | Boone      | boon     | boone      | {'Number': 'Sing'}                        |
# | Accenture  | accentur | accenture  | {'Number': 'Sing'}                        |
# | --         | --       | --         | {'PunctType': 'Peri'}                     |
# | Houston    | houston  | Houston    | {'Number': 'Sing'}                        |
# | Consultant | consult  | consultant | {'Number': 'Sing'}                        |
# | --         | --       | --         | {'PunctType': 'Peri'}                     |
# | Energy     | energi   | energy     | {'Number': 'Sing'}                        |
# | (          | (        | (          | {'PunctSide': 'Ini', 'PunctType': 'Brck'} |
# | Octel      | octel    | octel      | {'Number': 'Sing'}                        |
# | )          | )        | )          | {'PunctSide': 'Fin', 'PunctType': 'Brck'} |
# | 713        | 713      | 713        | {'NumType': 'Card'}                       |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | 837        | 837      | 837        | {'NumType': 'Card'}                       |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | 1638       | 1638     | 1638       | {'NumType': 'Card'}                       |
# | (          | (        | (          | {'PunctSide': 'Ini', 'PunctType': 'Brck'} |
# | Client     | client   | client     | {'Number': 'Sing'}                        |
# | )          | )        | )          | {'PunctSide': 'Fin', 'PunctType': 'Brck'} |
# | 281        | 281      | 281        | {'NumType': 'Card'}                       |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | 848        | 848      | 848        | {'NumType': 'Card'}                       |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | 1619       | 1619     | 1619       | {'NumType': 'Card'}                       |
# | (          | (        | (          | {'PunctSide': 'Ini', 'PunctType': 'Brck'} |
# | C          | c        | c          | {'Number': 'Sing'}                        |
# | )          | )        | )          | {'PunctSide': 'Fin', 'PunctType': 'Brck'} |
# | 713        | 713      | 713        | {'NumType': 'Card'}                       |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | 306        | 306      | 306        | {'NumType': 'Card'}                       |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | 7940       | 7940     | 7940       | {'NumType': 'Card'}                       |
# | (          | (        | (          | {'PunctSide': 'Ini', 'PunctType': 'Brck'} |
# | H          | h        | h          | {'Number': 'Sing'}                        |
# | )          | )        | )          | {'PunctSide': 'Fin', 'PunctType': 'Brck'} |
# | 713        | 713      | 713        | {'NumType': 'Card'}                       |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | 864        | 864      | 864        | {'NumType': 'Card'}                       |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | 4149       | 4149     | 4149       | {'NumType': 'Card'}                       |
# | Kevin      | kevin    | Kevin      | {'Number': 'Sing'}                        |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | A          | a        | a          | {'Definite': 'Ind', 'PronType': 'Art'}    |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | Boone      | boon     | boone      | {'Number': 'Sing'}                        |
# | @          | @        | @          | {'PunctType': 'Peri'}                     |
# | accenture  | accentur | accenture  | {'Number': 'Sing'}                        |
# | .          | .        | .          | {'PunctType': 'Peri'}                     |
# | com        | com      | com        | {'Number': 'Sing'}                        |
# +------------+----------+------------+-------------------------------------------+
# Sentence: if you do have a male but they are not in the same cage or breeding but you touch him then her she will smell his sent and probably lay eggs .
# +----------+---------+----------+---------------------------------------------------------------------------------------+
# | word     | stem    | lemma    | morphological_info                                                                    |
# |----------+---------+----------+---------------------------------------------------------------------------------------|
# | if       | if      | if       | {}                                                                                    |
# | you      | you     | you      | {'Person': '2', 'PronType': 'Prs'}                                                    |
# | do       | do      | do       | {'Mood': 'Ind', 'Tense': 'Pres', 'VerbForm': 'Fin'}                                   |
# | have     | have    | have     | {'VerbForm': 'Inf'}                                                                   |
# | a        | a       | a        | {'Definite': 'Ind', 'PronType': 'Art'}                                                |
# | male     | male    | male     | {'Number': 'Sing'}                                                                    |
# | but      | but     | but      | {'ConjType': 'Cmp'}                                                                   |
# | they     | they    | they     | {'Case': 'Nom', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}                   |
# | are      | are     | be       | {'Mood': 'Ind', 'Tense': 'Pres', 'VerbForm': 'Fin'}                                   |
# | not      | not     | not      | {'Polarity': 'Neg'}                                                                   |
# | in       | in      | in       | {}                                                                                    |
# | the      | the     | the      | {'Definite': 'Def', 'PronType': 'Art'}                                                |
# | same     | same    | same     | {'Degree': 'Pos'}                                                                     |
# | cage     | cage    | cage     | {'Number': 'Sing'}                                                                    |
# | or       | or      | or       | {'ConjType': 'Cmp'}                                                                   |
# | breeding | breed   | breed    | {'Aspect': 'Prog', 'Tense': 'Pres', 'VerbForm': 'Part'}                               |
# | but      | but     | but      | {'ConjType': 'Cmp'}                                                                   |
# | you      | you     | you      | {'Person': '2', 'PronType': 'Prs'}                                                    |
# | touch    | touch   | touch    | {'VerbForm': 'Inf'}                                                                   |
# | him      | him     | he       | {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'} |
# | then     | then    | then     | {'PronType': 'Dem'}                                                                   |
# | her      | her     | her      | {'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}  |
# | she      | she     | she      | {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}  |
# | will     | will    | will     | {'VerbForm': 'Fin'}                                                                   |
# | smell    | smell   | smell    | {'VerbForm': 'Inf'}                                                                   |
# | his      | his     | his      | {'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'} |
# | sent     | sent    | send     | {'Tense': 'Past', 'VerbForm': 'Fin'}                                                  |
# | and      | and     | and      | {'ConjType': 'Cmp'}                                                                   |
# | probably | probabl | probably | {}                                                                                    |
# | lay      | lay     | lay      | {'VerbForm': 'Inf'}                                                                   |
# | eggs     | egg     | egg      | {'Number': 'Plur'}                                                                    |
# | .        | .       | .        | {'PunctType': 'Peri'}                                                                 |
# +----------+---------+----------+---------------------------------------------------------------------------------------+
# Sentence: Will come again !
# +--------+--------+---------+-----------------------+
# | word   | stem   | lemma   | morphological_info    |
# |--------+--------+---------+-----------------------|
# | Will   | will   | will    | {'VerbForm': 'Fin'}   |
# | come   | come   | come    | {'VerbForm': 'Inf'}   |
# | again  | again  | again   | {}                    |
# | !      | !      | !       | {'PunctType': 'Peri'} |
# +--------+--------+---------+-----------------------+
# Sentence: All you have to do is become a member and watch your earnings grow !
# +----------+--------+---------+--------------------------------------------------------------------------------------+
# | word     | stem   | lemma   | morphological_info                                                                   |
# |----------+--------+---------+--------------------------------------------------------------------------------------|
# | All      | all    | all     | {}                                                                                   |
# | you      | you    | you     | {'Person': '2', 'PronType': 'Prs'}                                                   |
# | have     | have   | have    | {'VerbForm': 'Inf'}                                                                  |
# | to       | to     | to      | {}                                                                                   |
# | do       | do     | do      | {'Mood': 'Ind', 'Tense': 'Pres', 'VerbForm': 'Fin'}                                  |
# | is       | is     | be      | {'Mood': 'Ind', 'Number': 'Sing', 'Person': '3', 'Tense': 'Pres', 'VerbForm': 'Fin'} |
# | become   | becom  | become  | {'VerbForm': 'Inf'}                                                                  |
# | a        | a      | a       | {'Definite': 'Ind', 'PronType': 'Art'}                                               |
# | member   | member | member  | {'Number': 'Sing'}                                                                   |
# | and      | and    | and     | {'ConjType': 'Cmp'}                                                                  |
# | watch    | watch  | watch   | {'VerbForm': 'Inf'}                                                                  |
# | your     | your   | your    | {'Person': '2', 'Poss': 'Yes', 'PronType': 'Prs'}                                    |
# | earnings | earn   | earning | {'Number': 'Plur'}                                                                   |
# | grow     | grow   | grow    | {'VerbForm': 'Inf'}                                                                  |
# | !        | !      | !       | {'PunctType': 'Peri'}                                                                |
# +----------+--------+---------+--------------------------------------------------------------------------------------+
# Sentence: i have not gotten a good response so i think shanna and i are going to stay in town .
# +----------+---------+----------+---------------------------------------------------------------------+
# | word     | stem    | lemma    | morphological_info                                                  |
# |----------+---------+----------+---------------------------------------------------------------------|
# | i        | i       | I        | {'Case': 'Nom', 'Number': 'Sing', 'Person': '1', 'PronType': 'Prs'} |
# | have     | have    | have     | {'VerbForm': 'Inf'}                                                 |
# | not      | not     | not      | {'Polarity': 'Neg'}                                                 |
# | gotten   | gotten  | get      | {'Aspect': 'Perf', 'Tense': 'Past', 'VerbForm': 'Part'}             |
# | a        | a       | a        | {'Definite': 'Ind', 'PronType': 'Art'}                              |
# | good     | good    | good     | {'Degree': 'Pos'}                                                   |
# | response | respons | response | {'Number': 'Sing'}                                                  |
# | so       | so      | so       | {}                                                                  |
# | i        | i       | I        | {'Case': 'Nom', 'Number': 'Sing', 'Person': '1', 'PronType': 'Prs'} |
# | think    | think   | think    | {'VerbForm': 'Inf'}                                                 |
# | shanna   | shanna  | shanna   | {'Number': 'Sing'}                                                  |
# | and      | and     | and      | {'ConjType': 'Cmp'}                                                 |
# | i        | i       | I        | {'Case': 'Nom', 'Number': 'Sing', 'Person': '1', 'PronType': 'Prs'} |
# | are      | are     | be       | {'Mood': 'Ind', 'Tense': 'Pres', 'VerbForm': 'Fin'}                 |
# | going    | go      | go       | {'Aspect': 'Prog', 'Tense': 'Pres', 'VerbForm': 'Part'}             |
# | to       | to      | to       | {}                                                                  |
# | stay     | stay    | stay     | {'VerbForm': 'Inf'}                                                 |
# | in       | in      | in       | {}                                                                  |
# | town     | town    | town     | {'Number': 'Sing'}                                                  |
# | .        | .       | .        | {'PunctType': 'Peri'}                                               |
# +----------+---------+----------+---------------------------------------------------------------------+
# Sentence: Both Tina and Vicky are excellent .
# +-----------+--------+-----------+-----------------------------------------------------+
# | word      | stem   | lemma     | morphological_info                                  |
# |-----------+--------+-----------+-----------------------------------------------------|
# | Both      | both   | both      | {}                                                  |
# | Tina      | tina   | Tina      | {'Number': 'Sing'}                                  |
# | and       | and    | and       | {'ConjType': 'Cmp'}                                 |
# | Vicky     | vicki  | vicky     | {'Number': 'Sing'}                                  |
# | are       | are    | be        | {'Mood': 'Ind', 'Tense': 'Pres', 'VerbForm': 'Fin'} |
# | excellent | excel  | excellent | {'Degree': 'Pos'}                                   |
# | .         | .      | .         | {'PunctType': 'Peri'}                               |
# +-----------+--------+-----------+-----------------------------------------------------+
